# %% [markdown]
# # importing libraries

# %%
import pandas as pd

# %% [markdown]
# # import csv file

# %%
df = pd.read_csv('data/owid-covid-data.csv')

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-08          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-09          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 383793      ZWE    Africa     Zimbabwe  2024-02-28     266355.0        0.0
# 383794      ZWE    Africa     Zimbabwe  2024-02-29     266355.0        0.0
# 383795      ZWE    Africa     Zimbabwe  2024-03-01     266355.0        0.0
# 383796      ZWE    Africa     Zimbabwe  2024-03-02     266355.0        0.0
# 383797      ZWE    Africa     Zimbabwe  2024-03-03     266358.0        3.0
#
# ...

# %% [markdown]
# # Creating a new df deaths with chosen columns

# %%
df_deaths = df[['continent', 'location', 'date', 'population', 'total_cases', 
    'new_cases', 'total_deaths', 'new_deaths',]].copy()

# %% [markdown]
# # Saving the df deaths as csv

# %%
df_deaths.to_csv('data/new_covid_deaths.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# # Creating a new df vaccination with chosen columns

# %%
df_vaccinations =df[['continent', 'location', 'date', 'total_tests', 'new_tests', 
    'new_vaccinations']].copy()

# %% [markdown]
# # Saving the df vaccinations as csv

# %%
df_deaths.to_csv('data/new_covid_vaccinations.csv', index=False)

# %% [markdown]
# ---

# %%
new_df = pd.read_excel('data/CovidDeaths.xlsx')

# %%
new_df
# Out:
#       iso_code continent     location       date  population  total_cases  \
# 0          AFG      Asia  Afghanistan 2020-02-24  38928341.0          1.0
# 1          AFG      Asia  Afghanistan 2020-02-25  38928341.0          1.0
# 2          AFG      Asia  Afghanistan 2020-02-26  38928341.0          1.0
# 3          AFG      Asia  Afghanistan 2020-02-27  38928341.0          1.0
# 4          AFG      Asia  Afghanistan 2020-02-28  38928341.0          1.0
# ...        ...       ...          ...        ...         ...          ...
# 85166      ZWE    Africa     Zimbabwe 2021-04-26  14862927.0      38102.0
# 85167      ZWE    Africa     Zimbabwe 2021-04-27  14862927.0      38164.0
# 85168      ZWE    Africa     Zimbabwe 2021-04-28  14862927.0      38191.0
# 85169      ZWE    Africa     Zimbabwe 2021-04-29  14862927.0      38235.0
# 85170      ZWE    Africa     Zimbabwe 2021-04-30  14862927.0      38257.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# ...

# %%
new_df.to_csv('data/covid_d.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 new_df.to_csv('data/covid_d.csv', index=False)
#
# NameError: name 'new_df' is not defined

# %%
new_df_v = pd.read_excel('data/CovidVaccinations.xlsx')

# %%
new_df_v
# Out:
#       iso_code continent     location       date  new_tests  total_tests  \
# 0          AFG      Asia  Afghanistan 2020-02-24        NaN          NaN
# 1          AFG      Asia  Afghanistan 2020-02-25        NaN          NaN
# 2          AFG      Asia  Afghanistan 2020-02-26        NaN          NaN
# 3          AFG      Asia  Afghanistan 2020-02-27        NaN          NaN
# 4          AFG      Asia  Afghanistan 2020-02-28        NaN          NaN
# ...        ...       ...          ...        ...        ...          ...
# 85166      ZWE    Africa     Zimbabwe 2021-04-26     1495.0     484446.0
# 85167      ZWE    Africa     Zimbabwe 2021-04-27     2355.0     486801.0
# 85168      ZWE    Africa     Zimbabwe 2021-04-28     2025.0     488826.0
# 85169      ZWE    Africa     Zimbabwe 2021-04-29        NaN          NaN
# 85170      ZWE    Africa     Zimbabwe 2021-04-30        NaN          NaN
#
#        total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# ...

# %%
new_df_v.to_csv('data/covid_v.csv', index=False)
